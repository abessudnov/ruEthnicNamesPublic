# %%
import pandas as pd

# Import classifier and create object
from ethnos_classifier import EthnosClassifier

clf = EthnosClassifier()
# Out:
# /home/tarasov/.local/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /home/tarasov/.local/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /home/tarasov/.local/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator SGDClassifier from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /home/tarasov/.local/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator Pipeline from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /home/tarasov/.local/lib/python3.8/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
# Predict classes for "example.csv" table and save results to "example_pred.csv"
clf.predict('../data/example.csv', 'example_pred.csv')
# Out:
# /home/tarasov/ruEthnicNamesPublic/mlPipeline/ethnos_classifier.py:75: UserWarning: Warning: Some names in your data contain characters different from russian letters, "-" character or space. Results for this names will be "INVALID" or 0.0 for probabilities
#   warnings.warn(

# %%
# Predict classes probabilities for "example.csv" table and save results to "example_pr_pred.csv"
clf.predict('../data/example.csv', 'example_pr_pred.csv', predict_probs=True)
# Out:
# /home/tarasov/ruEthnicNamesPublic/mlPipeline/ethnos_classifier.py:75: UserWarning: Warning: Some names in your data contain characters different from russian letters, "-" character or space. Results for this names will be "INVALID" or 0.0 for probabilities
#   warnings.warn(

# %%
pd.read_csv('example_pred.csv')
# Out:
#      first_name    last_name      ethnos agr_ethnos
# 0           Рая     Левтеева     Russian  BelRusUkr
# 1        Даниил     Леснухин     Russian  BelRusUkr
# 2      Айгулька  Гильмуллина     Bashkir    BashTat
# 3       Евгения       Котова     Russian  BelRusUkr
# 4        Максим      Ефремов     Russian  BelRusUkr
# ...         ...          ...         ...        ...
# 1995  Маргарита      Петрова     Russian  BelRusUkr
# 1996    Дмитрий     Гречищев     Russian  BelRusUkr
# 1997     Андрий      Соколов   Ukrainian  BelRusUkr
# 1998     Эльшад        Алиев       Tatar    BashTat
# 1999  Анастасия    Лёвочкина  Belarusian  BelRusUkr
#
# [2000 rows x 4 columns]

# %%
pd.read_csv('example_pr_pred.csv')
# Out:
#      first_name    last_name  Armenian_full  Azerbaijani_full  Bashkir_full  \
# 0           Рая     Левтеева        0.00000          0.000000      0.000000
# 1        Даниил     Леснухин        0.00000          0.000000      0.014584
# 2      Айгулька  Гильмуллина        0.00000          0.000000      0.501576
# 3       Евгения       Котова        0.00000          0.000000      0.000000
# 4        Максим      Ефремов        0.00000          0.077099      0.004250
# ...         ...          ...            ...               ...           ...
# 1995  Маргарита      Петрова        0.00037          0.000000      0.039401
# 1996    Дмитрий     Гречищев        0.00000          0.000000      0.000000
# 1997     Андрий      Соколов        0.00000          0.000000      0.000000
# 1998     Эльшад        Алиев        0.00000          0.220733      0.000000
# 1999  Анастасия    Лёвочкина        0.00000          0.000000      0.000000
#
#       Belarusian_full  Buryat_full  Chechen_full  Dagestani_full  \
# 0            0.152974     0.141745           0.0        0.000000
# 1            0.458338     0.000000           0.0        0.000000
# 2            0.000000     0.000000           0.0        0.000000
# 3            0.039650     0.118874           0.0        0.000000
# 4            0.000000     0.000000           0.0        0.152316
# ...               ...          ...           ...             ...
# 1995         0.227905     0.124458           0.0        0.000000
# 1996         0.387682     0.117094           0.0        0.000000
# 1997         0.000000     0.003445           0.0        0.000000
# 1998         0.000000     0.086159           0.0        0.038911
# 1999         0.464015     0.000000           0.0        0.000000
#
#       Georgian_full  ...  CheDagIng_agr  Georgian_agr  Jewish_agr  \
# 0               0.0  ...            0.0      0.000000         0.0
# 1               0.0  ...            0.0      0.012316         0.0
# 2               0.0  ...            0.0      0.000000         0.0
# 3               0.0  ...            0.0      0.000000         0.0
# 4               0.0  ...            0.0      0.000000         0.0
# ...             ...  ...            ...           ...         ...
# 1995            0.0  ...            0.0      0.000000         0.0
# 1996            0.0  ...            0.0      0.000000         0.0
# 1997            0.0  ...            0.0      0.000000         0.0
# 1998            0.0  ...            0.0      0.000000         0.0
# 1999            0.0  ...            0.0      0.000000         0.0
#
#       KabAdKarBalOs_agr  Kalmyk_agr  KazKyr_agr  Moldovan_agr  TajUzb_agr  \
# 0              0.098063    0.132944    0.000000           0.0    0.000000
# 1              0.000000    0.000000    0.000000           0.0    0.000000
# 2              0.000000    0.000000    0.000000           0.0    0.000000
# 3              0.056571    0.000000    0.000000           0.0    0.000000
# 4              0.000000    0.000000    0.000000           0.0    0.000000
# ...                 ...         ...         ...           ...         ...
# 1995           0.000000    0.000000    0.133229           0.0    0.000000
# 1996           0.000000    0.000000    0.000000           0.0    0.000000
# 1997           0.000000    0.000000    0.000000           0.0    0.081465
# 1998           0.000000    0.000000    0.173849           0.0    0.000000
# 1999           0.000000    0.000000    0.000000           0.0    0.000000
#
#       Tuvan_agr  Yakut_agr
# 0           0.0   0.000000
# 1           0.0   0.000000
# 2           0.0   0.000000
# 3           0.0   0.000000
# 4           0.0   0.000000
# ...         ...        ...
# 1995        0.0   0.000000
# 1996        0.0   0.027327
# 1997        0.0   0.000000
# 1998        0.0   0.000000
# 1999        0.0   0.000000
#
# [2000 rows x 41 columns]
